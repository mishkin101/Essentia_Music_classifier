# %% [markdown]
# #. 1 Get the waveform of the sound
# #. 2 Get the spectrum
# #. 3 create mel spectrograms of all the sounds
# -----
# #. 5 Working with Fourier transforms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Timbre Description
